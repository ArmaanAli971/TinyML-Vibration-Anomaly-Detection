# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from pathlib import Path

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

print("TensorFlow version:", tf.__version__)

# %%
PROJECT_ROOT = Path.cwd().parent

if not (PROJECT_ROOT / "data").exists():
    PROJECT_ROOT = Path.cwd()

CWRU_DIR = (
    PROJECT_ROOT
    / "data"
    / "processed"
    / "CWRU"
)

WINDOW_DIR = CWRU_DIR / "windows"

MODEL_DIR = PROJECT_ROOT / "models"

RESULTS_DIR = PROJECT_ROOT / "results"

RESULTS_DIR.mkdir(
    parents=True,
    exist_ok=True
)

print("Project root:")
print(PROJECT_ROOT)

print("\nCWRU directory:")
print(CWRU_DIR)

print("\nWindow directory:")
print(WINDOW_DIR)

print("\nModel directory:")
print(MODEL_DIR)

print("\nResults directory:")
print(RESULTS_DIR)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 PROJECT_ROOT = Path.cwd().parent
#       3 if not (PROJECT_ROOT / "data").exists():
#       4     PROJECT_ROOT = Path.cwd()
#
# NameError: name 'Path' is not defined

# %%
FP32_MODEL_PATH = MODEL_DIR / "vaac_tiny_best.keras"

print("FP32 model:")
print(FP32_MODEL_PATH)

print("Exists:", FP32_MODEL_PATH.exists())
